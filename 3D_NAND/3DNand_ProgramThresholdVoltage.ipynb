# %% [markdown]
# 1.Generating CSV Data

# %%
import pandas as pd
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# Number of samples
n_train_samples = 1000
n_test_samples = 200

# Total number of samples (training + testing)
n_samples = n_train_samples + n_test_samples

# Generate random data for the given features
data = {
    'temperature': np.random.uniform(20, 100, n_samples),  # Random temperatures between 20°C and 100°C
    'doping_concentration': np.random.uniform(1e16, 1e18, n_samples),  # Doping concentration (atoms/cm³)
    'thickness_oxide_nitride_oxide': np.random.uniform(3.0, 10.0, n_samples),  # Thickness in nm
    'gate_metal_work_function': np.random.uniform(4.0, 5.5, n_samples),  # Work function in eV
    'program_voltage': np.random.uniform(15, 25, n_samples),  # Program voltage in V
    'erase_voltage': np.random.uniform(10, 20, n_samples),  # Erase voltage in V
    'channel_thickness': np.random.uniform(5.0, 15.0, n_samples),  # Channel thickness in nm
    'tunnel_oxide_thickness': np.random.uniform(1.5, 5.0, n_samples),  # Tunnel oxide thickness in nm
    'metal_gate_work_function': np.random.uniform(4.0, 5.5, n_samples),  # Work function in eV
    'program_time': np.random.uniform(1e-6, 1e-3, n_samples)  # Program time in seconds
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Generate the 'program_threshold_voltage' as a function of the above features with added noise
df['program_threshold_voltage'] = (
    0.02 * df['temperature'] +
    1e-17 * df['doping_concentration'] +
    0.05 * df['thickness_oxide_nitride_oxide'] +
    0.04 * df['gate_metal_work_function'] +
    0.07 * df['program_voltage'] +
    0.01 * df['program_time'] -
    0.02 * df['erase_voltage'] +
    0.06 * df['channel_thickness'] +
    0.07 * df['tunnel_oxide_thickness'] +
    0.05 * df['metal_gate_work_function'] +
    np.random.normal(0, 0.3, n_samples)  # Adding some noise
)

# Assign the last 20% of samples as test data by adding a column to indicate "train" or "test"
df['data_type'] = ['train'] * n_train_samples + ['test'] * n_test_samples

# Save the DataFrame to a CSV file
csv_file_name = 'nand_flash_program_threshold_data.csv'
df.to_csv(csv_file_name, index=False)

print(f"Generated training and testing data saved to {csv_file_name}")
# Out:
# Generated training and testing data saved to nand_flash_program_threshold_data.csv

# %% [markdown]
# 2.Load and Prepare the Data

# %%
import pandas as pd

# Load the CSV file
data = pd.read_csv('nand_flash_program_threshold_data.csv')

# Separate the training and testing data based on the 'data_type' column
train_data = data[data['data_type'] == 'train'].drop('data_type', axis=1)
test_data = data[data['data_type'] == 'test'].drop('data_type', axis=1)

# Split training data into input (X_train) and output (y_train)
X_train = train_data.drop('program_threshold_voltage', axis=1)
y_train = train_data['program_threshold_voltage']

# Split testing data into input (X_test) and output (y_test)
X_test = test_data.drop('program_threshold_voltage', axis=1)
y_test = test_data['program_threshold_voltage']

print("Training and testing data loaded and split successfully.")
# Out:
# Training and testing data loaded and split successfully.

# %% [markdown]
# 3.Preprocess and Train the Model

# %%
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Step 1: Scale the Input Features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Define an Advanced Neural Network Model
model = Sequential()

# Input Layer
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Hidden Layer 1
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

# Hidden Layer 2
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

# Hidden Layer 3
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Output Layer
model.add(Dense(1, activation='linear'))  # Linear activation for regression

# Step 3: Compile the Model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])

# Step 4: Learning Rate Scheduler to Improve Training
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=10, factor=0.5, min_lr=0.00001)

# Step 5: Train the Model
history = model.fit(X_train_scaled, y_train,
                    validation_data=(X_test_scaled, y_test),
                    epochs=200,
                    batch_size=32,
                    callbacks=[lr_reduction])

# Step 6: Save the Model for Future Predictions
model.save('advanced_nn_program_threshold_model.h5')

# Step 7: Evaluate the Model on Test Data
loss, mae = model.evaluate(X_test_scaled, y_test)
print(f'Mean Absolute Error on test set: {mae}')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 83.5467 - mae: 8.7215 - val_loss: 71.4727 - val_mae: 8.0494 - learning_rate: 0.0010
# Epoch 2/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 68.3978 - mae: 8.0183 - val_loss: 59.2696 - val_mae: 7.3118 - learning_rate: 0.0010
# Epoch 3/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 55.1321 - mae: 7.1699 - val_loss: 44.7658 - val_mae: 6.3108 - learning_rate: 0.0010
# Epoch 4/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 43.7769 - mae: 6.3028 - val_loss: 30.0993 - val_mae: 5.1457 - learning_rate: 0.0010
# Epoch 5/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 28.2725 - mae: 4.8954 - val_loss: 19.0017 - val_mae: 3.9940 - learning_rate: 0.0010
# Epoch 6/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.7855 - mae: 3.4203 - val_loss: 3.9115 - val_mae: 1.5972 - learning_rate: 0.0010
# Epoch 7/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.5464 - mae: 2.3550 - val_loss: 2.6794 - val_mae: 1.2901 - learning_rate: 0.0010
# Epoch 8/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.5437 - mae: 2.1330 - val_loss: 2.9330 - val_mae: 1.4513 - learning_rate: 0.0010
# Epoch 9/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3228 - mae: 2.0103 - val_loss: 1.2333 - val_mae: 0.8923 - learning_rate: 0.0010
# Epoch 10/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.3618 - mae: 1.9931 - val_loss: 1.4195 - val_mae: 0.9521 - learning_rate: 0.0010
# Epoch 11/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.3227 - mae: 1.8197 - val_loss: 1.1662 - val_mae: 0.8354 - learning_rate: 0.0010
# Epoch 12/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.5285 - mae: 1.8436 - val_loss: 1.3129 - val_mae: 0.8903 - learning_rate: 0.0010
# Epoch 13/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7026 - mae: 1.8573 - val_loss: 1.4726 - val_mae: 0.9748 - learning_rate: 0.0010
# Epoch 14/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0310 - mae: 1.9395 - val_loss: 1.3359 - val_mae: 0.9038 - learning_rate: 0.0010
# Epoch 15/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4564 - mae: 1.6567 - val_loss: 0.6983 - val_mae: 0.6914 - learning_rate: 0.0010
# Epoch 16/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6280 - mae: 1.7058 - val_loss: 1.0899 - val_mae: 0.8072 - learning_rate: 0.0010
# Epoch 17/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4715 - mae: 1.6682 - val_loss: 0.7600 - val_mae: 0.6784 - learning_rate: 0.0010
# Epoch 18/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5746 - mae: 1.4630 - val_loss: 0.7419 - val_mae: 0.6873 - learning_rate: 0.0010
# Epoch 19/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9926 - mae: 1.5783 - val_loss: 0.7458 - val_mae: 0.6573 - learning_rate: 0.0010
# Epoch 20/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7572 - mae: 1.4982 - val_loss: 0.8385 - val_mae: 0.7059 - learning_rate: 0.0010
# Epoch 21/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4725 - mae: 1.4766 - val_loss: 0.7512 - val_mae: 0.7021 - learning_rate: 0.0010
# Epoch 22/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3014 - mae: 1.4290 - val_loss: 0.5213 - val_mae: 0.5513 - learning_rate: 0.0010
# Epoch 23/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.5225 - mae: 1.4742 - val_loss: 0.6878 - val_mae: 0.6372 - learning_rate: 0.0010
# Epoch 24/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1748 - mae: 1.4350 - val_loss: 0.4859 - val_mae: 0.5613 - learning_rate: 0.0010
# Epoch 25/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1206 - mae: 1.3972 - val_loss: 0.4468 - val_mae: 0.5320 - learning_rate: 0.0010
# Epoch 26/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5854 - mae: 1.2838 - val_loss: 0.4571 - val_mae: 0.5294 - learning_rate: 0.0010
# Epoch 27/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5391 - mae: 1.2518 - val_loss: 0.4192 - val_mae: 0.5243 - learning_rate: 0.0010
# Epoch 28/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.9367 - mae: 1.3447 - val_loss: 0.4044 - val_mae: 0.5323 - learning_rate: 0.0010
# Epoch 29/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2478 - mae: 1.1753 - val_loss: 0.4265 - val_mae: 0.5235 - learning_rate: 0.0010
# Epoch 30/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6685 - mae: 1.2791 - val_loss: 0.5748 - val_mae: 0.5836 - learning_rate: 0.0010
# Epoch 31/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5394 - mae: 1.2501 - val_loss: 0.5116 - val_mae: 0.5661 - learning_rate: 0.0010
# Epoch 32/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3557 - mae: 1.2230 - val_loss: 0.4192 - val_mae: 0.5016 - learning_rate: 0.0010
# Epoch 33/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5779 - mae: 1.2667 - val_loss: 0.3572 - val_mae: 0.4844 - learning_rate: 0.0010
# Epoch 34/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5965 - mae: 1.2480 - val_loss: 0.3039 - val_mae: 0.4343 - learning_rate: 0.0010
# Epoch 35/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7193 - mae: 1.2940 - val_loss: 0.4783 - val_mae: 0.5662 - learning_rate: 0.0010
# Epoch 36/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.5921 - mae: 1.2644 - val_loss: 0.4755 - val_mae: 0.5314 - learning_rate: 0.0010
# Epoch 37/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0504 - mae: 1.1398 - val_loss: 0.2832 - val_mae: 0.4216 - learning_rate: 0.0010
# Epoch 38/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9745 - mae: 1.1073 - val_loss: 0.3479 - val_mae: 0.4606 - learning_rate: 0.0010
# Epoch 39/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3344 - mae: 1.1939 - val_loss: 0.3022 - val_mae: 0.4364 - learning_rate: 0.0010
# Epoch 40/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2248 - mae: 1.1922 - val_loss: 0.3972 - val_mae: 0.5178 - learning_rate: 0.0010
# Epoch 41/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3614 - mae: 1.2219 - val_loss: 0.3213 - val_mae: 0.4452 - learning_rate: 0.0010
# Epoch 42/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1913 - mae: 1.1468 - val_loss: 0.2749 - val_mae: 0.4279 - learning_rate: 0.0010
# Epoch 43/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2385 - mae: 1.1827 - val_loss: 0.2671 - val_mae: 0.4044 - learning_rate: 0.0010
# Epoch 44/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9093 - mae: 1.1035 - val_loss: 0.2619 - val_mae: 0.4158 - learning_rate: 0.0010
# Epoch 45/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3306 - mae: 1.1821 - val_loss: 0.4225 - val_mae: 0.5308 - learning_rate: 0.0010
# Epoch 46/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0145 - mae: 1.0943 - val_loss: 0.2224 - val_mae: 0.3768 - learning_rate: 0.0010
# Epoch 47/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0287 - mae: 1.1152 - val_loss: 0.2810 - val_mae: 0.4204 - learning_rate: 0.0010
# Epoch 48/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8442 - mae: 1.0599 - val_loss: 0.3070 - val_mae: 0.4457 - learning_rate: 0.0010
# Epoch 49/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9692 - mae: 1.1165 - val_loss: 0.2253 - val_mae: 0.3788 - learning_rate: 0.0010
# Epoch 50/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9020 - mae: 1.0822 - val_loss: 0.2615 - val_mae: 0.4071 - learning_rate: 0.0010
# Epoch 51/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4806 - mae: 0.9484 - val_loss: 0.2361 - val_mae: 0.3964 - learning_rate: 0.0010
# Epoch 52/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9758 - mae: 1.0954 - val_loss: 0.2353 - val_mae: 0.3919 - learning_rate: 0.0010
# Epoch 53/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6940 - mae: 1.0443 - val_loss: 0.2156 - val_mae: 0.3699 - learning_rate: 0.0010
# Epoch 54/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6343 - mae: 1.0226 - val_loss: 0.2825 - val_mae: 0.4339 - learning_rate: 0.0010
# Epoch 55/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7500 - mae: 1.0427 - val_loss: 0.2919 - val_mae: 0.4441 - learning_rate: 0.0010
# Epoch 56/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6563 - mae: 0.9900 - val_loss: 0.2326 - val_mae: 0.3918 - learning_rate: 0.0010
# Epoch 57/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3295 - mae: 0.9232 - val_loss: 0.2170 - val_mae: 0.3742 - learning_rate: 0.0010
# Epoch 58/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4345 - mae: 0.9414 - val_loss: 0.1854 - val_mae: 0.3445 - learning_rate: 0.0010
# Epoch 59/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4937 - mae: 0.9668 - val_loss: 0.1910 - val_mae: 0.3570 - learning_rate: 0.0010
# Epoch 60/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5626 - mae: 0.9846 - val_loss: 0.2252 - val_mae: 0.3876 - learning_rate: 0.0010
# Epoch 61/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8456 - mae: 1.0929 - val_loss: 0.2237 - val_mae: 0.3897 - learning_rate: 0.0010
# Epoch 62/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4243 - mae: 0.9363 - val_loss: 0.2156 - val_mae: 0.3762 - learning_rate: 0.0010
# Epoch 63/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7031 - mae: 1.0099 - val_loss: 0.1913 - val_mae: 0.3498 - learning_rate: 0.0010
# Epoch 64/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4728 - mae: 0.9771 - val_loss: 0.1983 - val_mae: 0.3538 - learning_rate: 0.0010
# Epoch 65/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3635 - mae: 0.9068 - val_loss: 0.2593 - val_mae: 0.4114 - learning_rate: 0.0010
# Epoch 66/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6174 - mae: 0.9970 - val_loss: 0.1769 - val_mae: 0.3271 - learning_rate: 0.0010
# Epoch 67/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4027 - mae: 0.9272 - val_loss: 0.1905 - val_mae: 0.3409 - learning_rate: 0.0010
# Epoch 68/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5244 - mae: 0.9789 - val_loss: 0.2022 - val_mae: 0.3553 - learning_rate: 0.0010
# Epoch 69/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4844 - mae: 0.9437 - val_loss: 0.2575 - val_mae: 0.4108 - learning_rate: 0.0010
# Epoch 70/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4757 - mae: 0.9595 - val_loss: 0.2241 - val_mae: 0.3710 - learning_rate: 0.0010
# Epoch 71/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4968 - mae: 0.9669 - val_loss: 0.2331 - val_mae: 0.3768 - learning_rate: 0.0010
# Epoch 72/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3736 - mae: 0.9261 - val_loss: 0.1857 - val_mae: 0.3354 - learning_rate: 0.0010
# Epoch 73/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2438 - mae: 0.8850 - val_loss: 0.2486 - val_mae: 0.3919 - learning_rate: 0.0010
# Epoch 74/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4597 - mae: 0.9468 - val_loss: 0.1729 - val_mae: 0.3368 - learning_rate: 0.0010
# Epoch 75/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4231 - mae: 0.9439 - val_loss: 0.1782 - val_mae: 0.3418 - learning_rate: 0.0010
# Epoch 76/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2774 - mae: 0.9083 - val_loss: 0.1658 - val_mae: 0.3248 - learning_rate: 0.0010
# Epoch 77/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1548 - mae: 0.8448 - val_loss: 0.1868 - val_mae: 0.3517 - learning_rate: 0.0010
# Epoch 78/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3114 - mae: 0.8855 - val_loss: 0.2105 - val_mae: 0.3584 - learning_rate: 0.0010
# Epoch 79/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2213 - mae: 0.8676 - val_loss: 0.1537 - val_mae: 0.3142 - learning_rate: 0.0010
# Epoch 80/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3628 - mae: 0.9126 - val_loss: 0.1988 - val_mae: 0.3570 - learning_rate: 0.0010
# Epoch 81/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3976 - mae: 0.9200 - val_loss: 0.1609 - val_mae: 0.3226 - learning_rate: 0.0010
# Epoch 82/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2045 - mae: 0.8541 - val_loss: 0.1518 - val_mae: 0.3219 - learning_rate: 0.0010
# Epoch 83/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1619 - mae: 0.8496 - val_loss: 0.1499 - val_mae: 0.3145 - learning_rate: 0.0010
# Epoch 84/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3258 - mae: 0.9200 - val_loss: 0.1428 - val_mae: 0.3095 - learning_rate: 0.0010
# Epoch 85/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0387 - mae: 0.7886 - val_loss: 0.1640 - val_mae: 0.3246 - learning_rate: 0.0010
# Epoch 86/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3373 - mae: 0.9138 - val_loss: 0.1533 - val_mae: 0.3094 - learning_rate: 0.0010
# Epoch 87/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2370 - mae: 0.8797 - val_loss: 0.1717 - val_mae: 0.3405 - learning_rate: 0.0010
# Epoch 88/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3378 - mae: 0.9307 - val_loss: 0.1497 - val_mae: 0.3095 - learning_rate: 0.0010
# Epoch 89/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3799 - mae: 0.9191 - val_loss: 0.1494 - val_mae: 0.3040 - learning_rate: 0.0010
# Epoch 90/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2489 - mae: 0.8838 - val_loss: 0.1430 - val_mae: 0.3010 - learning_rate: 0.0010
# Epoch 91/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1894 - mae: 0.8762 - val_loss: 0.3265 - val_mae: 0.4635 - learning_rate: 0.0010
# Epoch 92/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1966 - mae: 0.8438 - val_loss: 0.1755 - val_mae: 0.3447 - learning_rate: 0.0010
# Epoch 93/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1917 - mae: 0.8394 - val_loss: 0.1439 - val_mae: 0.3023 - learning_rate: 0.0010
# Epoch 94/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3039 - mae: 0.8852 - val_loss: 0.1671 - val_mae: 0.3194 - learning_rate: 0.0010
# Epoch 95/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1774 - mae: 0.8675 - val_loss: 0.1467 - val_mae: 0.3086 - learning_rate: 5.0000e-04
# Epoch 96/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1514 - mae: 0.8435 - val_loss: 0.1517 - val_mae: 0.3117 - learning_rate: 5.0000e-04
# Epoch 97/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1185 - mae: 0.8041 - val_loss: 0.1561 - val_mae: 0.3117 - learning_rate: 5.0000e-04
# Epoch 98/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2029 - mae: 0.8634 - val_loss: 0.1381 - val_mae: 0.2926 - learning_rate: 5.0000e-04
# Epoch 99/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0368 - mae: 0.8002 - val_loss: 0.1440 - val_mae: 0.2999 - learning_rate: 5.0000e-04
# Epoch 100/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1173 - mae: 0.8253 - val_loss: 0.1610 - val_mae: 0.3177 - learning_rate: 5.0000e-04
# Epoch 101/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2968 - mae: 0.9095 - val_loss: 0.1418 - val_mae: 0.3059 - learning_rate: 5.0000e-04
# Epoch 102/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.9571 - mae: 0.7801 - val_loss: 0.1330 - val_mae: 0.2917 - learning_rate: 5.0000e-04
# Epoch 103/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1179 - mae: 0.8345 - val_loss: 0.1409 - val_mae: 0.2978 - learning_rate: 5.0000e-04
# Epoch 104/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0502 - mae: 0.8169 - val_loss: 0.1334 - val_mae: 0.2946 - learning_rate: 5.0000e-04
# Epoch 105/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0804 - mae: 0.8207 - val_loss: 0.1356 - val_mae: 0.2935 - learning_rate: 5.0000e-04
# Epoch 106/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3485 - mae: 0.9196 - val_loss: 0.1295 - val_mae: 0.2921 - learning_rate: 5.0000e-04
# Epoch 107/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9829 - mae: 0.7688 - val_loss: 0.1315 - val_mae: 0.2924 - learning_rate: 5.0000e-04
# Epoch 108/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9683 - mae: 0.7606 - val_loss: 0.1207 - val_mae: 0.2762 - learning_rate: 5.0000e-04
# Epoch 109/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0573 - mae: 0.8033 - val_loss: 0.1271 - val_mae: 0.2843 - learning_rate: 5.0000e-04
# Epoch 110/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0205 - mae: 0.7772 - val_loss: 0.1320 - val_mae: 0.2868 - learning_rate: 5.0000e-04
# Epoch 111/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8908 - mae: 0.7430 - val_loss: 0.1359 - val_mae: 0.2944 - learning_rate: 5.0000e-04
# Epoch 112/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0290 - mae: 0.8022 - val_loss: 0.1303 - val_mae: 0.2901 - learning_rate: 5.0000e-04
# Epoch 113/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0893 - mae: 0.8335 - val_loss: 0.1220 - val_mae: 0.2800 - learning_rate: 5.0000e-04
# Epoch 114/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1863 - mae: 0.8648 - val_loss: 0.1218 - val_mae: 0.2847 - learning_rate: 5.0000e-04
# Epoch 115/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0650 - mae: 0.8083 - val_loss: 0.1161 - val_mae: 0.2717 - learning_rate: 5.0000e-04
# Epoch 116/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1382 - mae: 0.8431 - val_loss: 0.1260 - val_mae: 0.2879 - learning_rate: 5.0000e-04
# Epoch 117/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0235 - mae: 0.7859 - val_loss: 0.1168 - val_mae: 0.2743 - learning_rate: 5.0000e-04
# Epoch 118/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0015 - mae: 0.7754 - val_loss: 0.1198 - val_mae: 0.2805 - learning_rate: 5.0000e-04
# Epoch 119/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0252 - mae: 0.7883 - val_loss: 0.1201 - val_mae: 0.2792 - learning_rate: 5.0000e-04
# Epoch 120/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0631 - mae: 0.8044 - val_loss: 0.1414 - val_mae: 0.2987 - learning_rate: 5.0000e-04
# Epoch 121/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2024 - mae: 0.8486 - val_loss: 0.1706 - val_mae: 0.3255 - learning_rate: 5.0000e-04
# Epoch 122/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0401 - mae: 0.8006 - val_loss: 0.1555 - val_mae: 0.3148 - learning_rate: 5.0000e-04
# Epoch 123/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1542 - mae: 0.8585 - val_loss: 0.1216 - val_mae: 0.2767 - learning_rate: 5.0000e-04
# Epoch 124/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2443 - mae: 0.9109 - val_loss: 0.1292 - val_mae: 0.2896 - learning_rate: 5.0000e-04
# Epoch 125/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9561 - mae: 0.7772 - val_loss: 0.1183 - val_mae: 0.2783 - learning_rate: 5.0000e-04
# Epoch 126/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9465 - mae: 0.7603 - val_loss: 0.1273 - val_mae: 0.2878 - learning_rate: 2.5000e-04
# Epoch 127/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9696 - mae: 0.7957 - val_loss: 0.1147 - val_mae: 0.2692 - learning_rate: 2.5000e-04
# Epoch 128/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0650 - mae: 0.8131 - val_loss: 0.1194 - val_mae: 0.2744 - learning_rate: 2.5000e-04
# Epoch 129/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0404 - mae: 0.7996 - val_loss: 0.1326 - val_mae: 0.2902 - learning_rate: 2.5000e-04
# Epoch 130/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9778 - mae: 0.7860 - val_loss: 0.1263 - val_mae: 0.2841 - learning_rate: 2.5000e-04
# Epoch 131/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2315 - mae: 0.8697 - val_loss: 0.1231 - val_mae: 0.2800 - learning_rate: 2.5000e-04
# Epoch 132/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1633 - mae: 0.8592 - val_loss: 0.1547 - val_mae: 0.3055 - learning_rate: 2.5000e-04
# Epoch 133/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0327 - mae: 0.8173 - val_loss: 0.1248 - val_mae: 0.2839 - learning_rate: 2.5000e-04
# Epoch 134/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1128 - mae: 0.8396 - val_loss: 0.1221 - val_mae: 0.2758 - learning_rate: 2.5000e-04
# Epoch 135/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8958 - mae: 0.7450 - val_loss: 0.1202 - val_mae: 0.2781 - learning_rate: 2.5000e-04
# Epoch 136/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9237 - mae: 0.7576 - val_loss: 0.1197 - val_mae: 0.2753 - learning_rate: 2.5000e-04
# Epoch 137/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1194 - mae: 0.8204 - val_loss: 0.1313 - val_mae: 0.2889 - learning_rate: 2.5000e-04
# Epoch 138/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9697 - mae: 0.7952 - val_loss: 0.1242 - val_mae: 0.2822 - learning_rate: 1.2500e-04
# Epoch 139/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0578 - mae: 0.7979 - val_loss: 0.1232 - val_mae: 0.2821 - learning_rate: 1.2500e-04
# Epoch 140/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9632 - mae: 0.7662 - val_loss: 0.1201 - val_mae: 0.2803 - learning_rate: 1.2500e-04
# Epoch 141/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8981 - mae: 0.7443 - val_loss: 0.1256 - val_mae: 0.2858 - learning_rate: 1.2500e-04
# Epoch 142/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0388 - mae: 0.8305 - val_loss: 0.1219 - val_mae: 0.2807 - learning_rate: 1.2500e-04
# Epoch 143/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8503 - mae: 0.7211 - val_loss: 0.1253 - val_mae: 0.2841 - learning_rate: 1.2500e-04
# Epoch 144/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9692 - mae: 0.7887 - val_loss: 0.1204 - val_mae: 0.2793 - learning_rate: 1.2500e-04
# Epoch 145/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0262 - mae: 0.8209 - val_loss: 0.1143 - val_mae: 0.2702 - learning_rate: 1.2500e-04
# Epoch 146/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0082 - mae: 0.7910 - val_loss: 0.1149 - val_mae: 0.2726 - learning_rate: 1.2500e-04
# Epoch 147/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0873 - mae: 0.8205 - val_loss: 0.1154 - val_mae: 0.2733 - learning_rate: 1.2500e-04
# Epoch 148/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0388 - mae: 0.8097 - val_loss: 0.1257 - val_mae: 0.2842 - learning_rate: 1.2500e-04
# Epoch 149/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.9308 - mae: 0.7584 - val_loss: 0.1249 - val_mae: 0.2817 - learning_rate: 1.2500e-04
# Epoch 150/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0567 - mae: 0.8224 - val_loss: 0.1225 - val_mae: 0.2799 - learning_rate: 1.2500e-04
# Epoch 151/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.1066 - mae: 0.8161 - val_loss: 0.1203 - val_mae: 0.2770 - learning_rate: 1.2500e-04
# Epoch 152/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0254 - mae: 0.8187 - val_loss: 0.1225 - val_mae: 0.2796 - learning_rate: 1.2500e-04
# Epoch 153/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9936 - mae: 0.7871 - val_loss: 0.1238 - val_mae: 0.2808 - learning_rate: 1.2500e-04
# Epoch 154/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1136 - mae: 0.8393 - val_loss: 0.1199 - val_mae: 0.2767 - learning_rate: 1.2500e-04
# Epoch 155/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0593 - mae: 0.8084 - val_loss: 0.1136 - val_mae: 0.2714 - learning_rate: 1.2500e-04
# Epoch 156/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8891 - mae: 0.7541 - val_loss: 0.1143 - val_mae: 0.2726 - learning_rate: 1.2500e-04
# Epoch 157/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0723 - mae: 0.8036 - val_loss: 0.1167 - val_mae: 0.2756 - learning_rate: 1.2500e-04
# Epoch 158/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8964 - mae: 0.7602 - val_loss: 0.1126 - val_mae: 0.2713 - learning_rate: 1.2500e-04
# Epoch 159/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9430 - mae: 0.7730 - val_loss: 0.1219 - val_mae: 0.2812 - learning_rate: 1.2500e-04
# Epoch 160/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9185 - mae: 0.7491 - val_loss: 0.1198 - val_mae: 0.2794 - learning_rate: 1.2500e-04
# Epoch 161/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1109 - mae: 0.8257 - val_loss: 0.1291 - val_mae: 0.2894 - learning_rate: 1.2500e-04
# Epoch 162/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.9359 - mae: 0.7521 - val_loss: 0.1143 - val_mae: 0.2712 - learning_rate: 1.2500e-04
# Epoch 163/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8485 - mae: 0.7204 - val_loss: 0.1233 - val_mae: 0.2810 - learning_rate: 1.2500e-04
# Epoch 164/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9643 - mae: 0.7867 - val_loss: 0.1157 - val_mae: 0.2734 - learning_rate: 1.2500e-04
# Epoch 165/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0718 - mae: 0.8149 - val_loss: 0.1157 - val_mae: 0.2736 - learning_rate: 1.2500e-04
# Epoch 166/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.0663 - mae: 0.8344 - val_loss: 0.1239 - val_mae: 0.2824 - learning_rate: 1.2500e-04
# Epoch 167/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8798 - mae: 0.7277 - val_loss: 0.1189 - val_mae: 0.2792 - learning_rate: 1.2500e-04
# Epoch 168/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9817 - mae: 0.7912 - val_loss: 0.1235 - val_mae: 0.2842 - learning_rate: 1.2500e-04
# Epoch 169/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8256 - mae: 0.7027 - val_loss: 0.1218 - val_mae: 0.2822 - learning_rate: 6.2500e-05
# Epoch 170/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8601 - mae: 0.7448 - val_loss: 0.1170 - val_mae: 0.2760 - learning_rate: 6.2500e-05
# Epoch 171/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0439 - mae: 0.8213 - val_loss: 0.1162 - val_mae: 0.2740 - learning_rate: 6.2500e-05
# Epoch 172/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0051 - mae: 0.7889 - val_loss: 0.1200 - val_mae: 0.2771 - learning_rate: 6.2500e-05
# Epoch 173/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0964 - mae: 0.8385 - val_loss: 0.1237 - val_mae: 0.2811 - learning_rate: 6.2500e-05
# Epoch 174/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2343 - mae: 0.8714 - val_loss: 0.1187 - val_mae: 0.2757 - learning_rate: 6.2500e-05
# Epoch 175/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9078 - mae: 0.7500 - val_loss: 0.1223 - val_mae: 0.2827 - learning_rate: 6.2500e-05
# Epoch 176/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0660 - mae: 0.8280 - val_loss: 0.1233 - val_mae: 0.2825 - learning_rate: 6.2500e-05
# Epoch 177/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8076 - mae: 0.7156 - val_loss: 0.1203 - val_mae: 0.2788 - learning_rate: 6.2500e-05
# Epoch 178/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9528 - mae: 0.7694 - val_loss: 0.1214 - val_mae: 0.2796 - learning_rate: 6.2500e-05
# Epoch 179/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9630 - mae: 0.7701 - val_loss: 0.1201 - val_mae: 0.2788 - learning_rate: 3.1250e-05
# Epoch 180/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8833 - mae: 0.7378 - val_loss: 0.1229 - val_mae: 0.2816 - learning_rate: 3.1250e-05
# Epoch 181/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9795 - mae: 0.7751 - val_loss: 0.1238 - val_mae: 0.2828 - learning_rate: 3.1250e-05
# Epoch 182/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9192 - mae: 0.7486 - val_loss: 0.1229 - val_mae: 0.2820 - learning_rate: 3.1250e-05
# Epoch 183/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9135 - mae: 0.7524 - val_loss: 0.1201 - val_mae: 0.2792 - learning_rate: 3.1250e-05
# Epoch 184/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1426 - mae: 0.8643 - val_loss: 0.1193 - val_mae: 0.2784 - learning_rate: 3.1250e-05
# Epoch 185/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7577 - mae: 0.6841 - val_loss: 0.1168 - val_mae: 0.2749 - learning_rate: 3.1250e-05
# Epoch 186/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.0359 - mae: 0.8186 - val_loss: 0.1170 - val_mae: 0.2743 - learning_rate: 3.1250e-05
# Epoch 187/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9590 - mae: 0.7560 - val_loss: 0.1179 - val_mae: 0.2750 - learning_rate: 3.1250e-05
# Epoch 188/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9553 - mae: 0.7720 - val_loss: 0.1192 - val_mae: 0.2759 - learning_rate: 3.1250e-05
# Epoch 189/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9345 - mae: 0.7529 - val_loss: 0.1206 - val_mae: 0.2786 - learning_rate: 1.5625e-05
# Epoch 190/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9975 - mae: 0.7919 - val_loss: 0.1185 - val_mae: 0.2761 - learning_rate: 1.5625e-05
# Epoch 191/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8976 - mae: 0.7670 - val_loss: 0.1177 - val_mae: 0.2757 - learning_rate: 1.5625e-05
# Epoch 192/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7786 - mae: 0.6781 - val_loss: 0.1195 - val_mae: 0.2773 - learning_rate: 1.5625e-05
# Epoch 193/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3283 - mae: 0.9223 - val_loss: 0.1181 - val_mae: 0.2756 - learning_rate: 1.5625e-05
# Epoch 194/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1383 - mae: 0.8614 - val_loss: 0.1188 - val_mae: 0.2765 - learning_rate: 1.5625e-05
# Epoch 195/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0620 - mae: 0.8128 - val_loss: 0.1191 - val_mae: 0.2762 - learning_rate: 1.5625e-05
# Epoch 196/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.8599 - mae: 0.7393 - val_loss: 0.1184 - val_mae: 0.2751 - learning_rate: 1.5625e-05
# Epoch 197/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2015 - mae: 0.8725 - val_loss: 0.1190 - val_mae: 0.2764 - learning_rate: 1.5625e-05
# Epoch 198/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9477 - mae: 0.7695 - val_loss: 0.1190 - val_mae: 0.2767 - learning_rate: 1.5625e-05
# Epoch 199/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8782 - mae: 0.7287 - val_loss: 0.1185 - val_mae: 0.2764 - learning_rate: 1.0000e-05
# Epoch 200/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9711 - mae: 0.7713 - val_loss: 0.1163 - val_mae: 0.2742 - learning_rate: 1.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1192 - mae: 0.2797
# Mean Absolute Error on test set: 0.2742305397987366

# %% [markdown]
# 4.Evaluating model on testing data

# %%
# Evaluate the model on the test data
loss, mae = model.evaluate(X_test_scaled, y_test)
print(f'Mean Absolute Error on the test set: {mae}')

# Get predictions on the test data
y_pred = model.predict(X_test_scaled)

# Compare first 5 predictions with actual values
print("Predicted vs Actual Program Threshold Voltage Values:")
for i in range(5):
    print(f"Sample {i+1}: Predicted = {y_pred[i][0]:.4f}, Actual = {y_test.iloc[i]:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1192 - mae: 0.2797
# Mean Absolute Error on the test set: 0.2742305397987366
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted vs Actual Program Threshold Voltage Values:
# Sample 1: Predicted = 12.6680, Actual = 13.0411
# Sample 2: Predicted = 4.7264, Actual = 5.0292
# Sample 3: Predicted = 8.9596, Actual = 8.7253
# Sample 4: Predicted = 4.9887, Actual = 4.6281
# Sample 5: Predicted = 11.9142, Actual = 11.6923

# %% [markdown]
# 5.Plotting Loss vs Epochs,Actual vs Predicted Values, Residuals

# %%
import matplotlib.pyplot as plt

# Plot the Loss vs Epochs
def plot_loss(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss vs Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the function to plot the loss curve
plot_loss(history)

print("\n\n")
# Plot Actual vs Predicted values
plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', label='Perfect Prediction Line')
plt.title('Actual vs Predicted Program Threshold Voltage')
plt.xlabel('Actual Program Threshold Voltage')
plt.ylabel('Predicted Program Threshold Voltage')
plt.legend()
plt.grid(True)
plt.show()

print("\n\n")
# Calculate residuals
residuals = y_test - y_pred.flatten()

# Plot Residuals
plt.scatter(y_test, residuals, color='purple', alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs Actual Program Threshold Voltage')
plt.xlabel('Actual Program Threshold Voltage')
plt.ylabel('Residuals')
plt.grid(True)
plt.show()

# Print basic statistics of residuals
print(f'Mean of Residuals: {np.mean(residuals):.4f}')
print(f'Standard Deviation of Residuals: {np.std(residuals):.4f}')
# Out:
# Mean of Residuals: 0.0254
# Standard Deviation of Residuals: 0.3401
